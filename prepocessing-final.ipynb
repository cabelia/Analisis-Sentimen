# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

import nltk
import json
import pandas as pd
import re
import emoji
import contractions
import openpyxl
nltk.download('stopwords')

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.util import ngrams
from pprint import pprint
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\canti\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv("craw_pln123_new.csv")
df = df[(df['username'] != 'pln_123')]
df
# Out:
#                     date         username  \
# 0    2022-07-01 06:59:09      rahinahu461
# 1    2022-07-01 06:55:51        nandosbs_
# 2    2022-07-01 06:54:10        BennyKeef
# 3    2022-07-01 06:36:42         aleendy_
# 5    2022-07-01 06:25:03  RudySigitPurwa1
# ..                   ...              ...
# 300  2022-06-30 14:02:04        UdinSykes
# 304  2022-06-30 13:54:13       ruangkata3
# 309  2022-06-30 13:46:30    Dwikodarmawan
# 310  2022-06-30 13:45:05         azeezy84
# 314  2022-06-30 13:28:53  fransiskanovin4
#
#                                                  tweet
# 0    @pln_123 Mohon maaf, sy tidak mencantumkan per...
# 1    @pln_123 Tindaklanjuti hanya dengan tulisan ka...
# 2    @pln_123 Min listrik di rmh ada masalah, saya ...
# 3                      @pln_123 halo min boleh cek DM?
# 5    @pln_123 Mudah mudahan 24 jam kedepan dan sete...
# ..                                                 ...
# 300  @pln_123 daerah balekambang, kramat jati, jaka...
# 304  @pln_123 2200 VA berarti masuknya ke R1 kan? D...
# 309  Assalamualaikum @pln_123 , kira kira sampe kap...
# 310  @pln_123 listrik area Salam, Magelang mati dar...
# 314  @pln_123 kak daerah malang singosari mati lamp...
#
# [156 rows x 3 columns]

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Case Folding & Cleansing text

# %%
twitter_handle = r'@(\w+)'                        # remove twitter handle (@username)
url_handle = r'http[^ ]+'                                  # remove website URLs that start with 'https?://'
combined_handle = r'|'.join((twitter_handle, url_handle))  # join
www_handle = '(http|https):\/\/\S+'                        # remove website URLs that start with 'www.'
punctuation_handle = r'\W+'
hastag_handle = r"#(\w+)"                                  # remove hastags
number_handle = '[0-9]'

def case_folding(text):
    ## Case Folding
    lowered_text = text.lower()
    ## remove twitter handle (@username)
    t1 = re.sub(twitter_handle, '', lowered_text)
    ## remove hastags
    t2 = re.sub(hastag_handle, '', t1)
    ## remove emoji
    t3 = emoji.replace_emoji(t2)
    ## remove website URLs that start with 'www.'
    t4 = re.sub(www_handle, '', t3)
    ## Punctuation Removal
    t5 = re.sub(punctuation_handle, ' ', t4)
    ## remove number 
    t6 = re.sub(number_handle, '', t5)
    ## replace contractions with their extended forms
    t7 = contractions.fix(t6)
    return t7

# %% [markdown]
# ### Slang Word

# %%
text = open("combined_slang_words.txt", "r",encoding="utf-8")
slang_words = text.read();text.close()
slang_words = json.loads(slang_words)

def slang_word(text):
    # split the words based on whitespace
    sentence_list = word_tokenize(text)

    for i,t in enumerate(sentence_list):
        if t in slang_words.keys():
            sentence_list[i] = slang_words[t] 
    
    text = ' '.join(sentence_list)
    return text

# %% [markdown]
# ### Stopword

# %%
def stopword(text):
    stop_words = stopwords.words('indonesian')
    list_negasi = ['tidak', 'jangan', 'enggak', 'belum', 'blm']
    stop_words = [word for word in stop_words if word not in list_negasi]
    text = word_tokenize(text)
    text = [w for w in text if not w in stop_words]
    sentence = ' '.join(text)
    return sentence

print(stopword("yang di rumah yang tidak jangan disitu"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13780/549011429.py in <module>
#       8     return sentence
#       9
# ---> 10 print(stopword("yang di rumah yang tidak jangan disitu"))
#
# ~\AppData\Local\Temp/ipykernel_13780/549011429.py in stopword(text)
#       1 def stopword(text):
# ----> 2     stop_words = stopwords.words('indonesian')
#       3     list_negasi = ['tidak', 'jangan', 'enggak', 'belum', 'blm']
#       4     stop_words = [word for word in stop_words if word not in list_negasi]
#       5     text = word_tokenize(text)
#
# NameError: name 'stopwords' is not defined

# %% [markdown]
# ### Stemming

# %%
factory = StemmerFactory()
stemmer = factory.create_stemmer()

def stemming(text):
    stemmed_text = stemmer.stem(text)
    return stemmed_text

# %% [markdown]
# ### Tokenize

# %%
def tokenize(text):
    return word_tokenize(text)

# %% [markdown]
# ## Apply Preprocessing to Data

# %%
result_list = []

for i, text in enumerate (df['tweet']):
    case_folding_text = case_folding(text)
    slang_word_text = slang_word(case_folding_text)
    stopword_text = stopword(slang_word_text)
    stemmed_text = stemming(stopword_text)
    tokenize_text = tokenize(stemmed_text)
    
    
    result_list.append([case_folding_text,
                        slang_word_text,
                        stopword_text,
                        stemmed_text,
                        tokenize_text])

case_folding_texts = []
slang_word_texts = []
stopword_texts = []
stemmed_texts = []
tokenize_texts = []

for i,text in enumerate(result_list):
    for k,word in enumerate(text):
        if k == 0:
            case_folding_texts.append(word)
        if k == 1:
            slang_word_texts.append(word)
        if k == 2:
            stopword_texts.append(word)
        if k == 3:
            stemmed_texts.append(word)
        if k == 4:
            tokenize_texts.append(word)

    
table_data = pd.DataFrame({
    'username' : df['username'],
    'tweet' : df['tweet'],
    'Case Folding': case_folding_texts,
    'Slang Word': slang_word_texts,
    'Stopword': stopword_texts,
    'Stemmed Text': stemmed_texts,
    'Tokenize Text': tokenize_texts
}) 

table_data.to_csv('preprocessing-final.csv',index=False)
table_data.to_excel('preprocessing-final.xlsx',index=False)

table_data
# Out:
#             username                                              tweet  \
# 0        rahinahu461  @pln_123 Mohon maaf, sy tidak mencantumkan per...
# 1          nandosbs_  @pln_123 Tindaklanjuti hanya dengan tulisan ka...
# 2          BennyKeef  @pln_123 Min listrik di rmh ada masalah, saya ...
# 3           aleendy_                    @pln_123 halo min boleh cek DM?
# 5    RudySigitPurwa1  @pln_123 Mudah mudahan 24 jam kedepan dan sete...
# ..               ...                                                ...
# 300        UdinSykes  @pln_123 daerah balekambang, kramat jati, jaka...
# 304       ruangkata3  @pln_123 2200 VA berarti masuknya ke R1 kan? D...
# 309    Dwikodarmawan  Assalamualaikum @pln_123 , kira kira sampe kap...
# 310         azeezy84  @pln_123 listrik area Salam, Magelang mati dar...
# 314  fransiskanovin4  @pln_123 kak daerah malang singosari mati lamp...
#
#                                           Case Folding  \
# 0     mohon maaf sy tidak mencantumkan permasalahan...
# 1     tindaklanjuti hanya dengan tulisan kan bukan ...
# 2     min listrik di rmh ada masalah saya coba hubu...
# 3                               halo min boleh cek dm
# 5     mudah mudahan  jam kedepan dan seterusnya ga ...
# ..                                                 ...
# 300   daerah balekambang kramat jati jakarta timur ...
# 304    va berarti masuknya ke r kan daya saya  va d...
# 309  assalamualaikum kira kira sampe kapan listrikn...
# 310   listrik area salam magelang mati dari pukul  ...
# 314   kak daerah malang singosari mati lampu sampai...
#
#                                             Slang Word  \
# 0    mohon maaf saya tidak mencantumkan permasalaha...
# 1    tindaklanjuti hanya dengan tulisan kan bukan d...
# 2    admin listrik di rumah ada masalah saya coba h...
# 3                              halo admin boleh cek dm
# 5    mudah mudahan jam kedepan dan seterusnya tidak...
# ..                                                 ...
# 300  daerah balekambang kramat jati jakarta timur s...
# 304  va berarti masuknya ke r kan daya saya va dan ...
# 309  assalamualaikum kira kira sampai kapan listrik...
# 310  listrik area salam magelang mati dari pukul an...
# 314  kakak daerah malang singosari mati lampu sampa...
#
#                                               Stopword  \
# 0    mohon maaf tidak mencantumkan permasalahan tuj...
# 1    tindaklanjuti tulisan aksi perubahan komplain ...
# 2    admin listrik rumah coba hubungi pln terdekat ...
# 3                                    halo admin cek dm
# 5            mudah mudahan jam kedepan tidak pemadaman
# ..                                                 ...
# 300  daerah balekambang kramat jati jakarta timur p...
# 304     va masuknya r daya va mengalami kenaikan tidak
# 309  assalamualaikum listriknya nyala daerah baleka...
# 310  listrik area salam magelang mati an pagi siang...
# 314       kakak daerah malang singosari mati lampu jam
#
#                                           Stemmed Text  \
# 0    mohon maaf tidak cantum masalah tuju lapor dug...
# 1    tindaklanjuti tulis aksi ubah komplain jam dir...
# 2    admin listrik rumah coba hubung pln dekat tida...
# 3                                    halo admin cek dm
# 5                    mudah mudah jam depan tidak madam
# ..                                                 ...
# 300  daerah balekambang kramat jati jakarta timur p...
# 304                va masuk r daya va alami naik tidak
# 309  assalamualaikum listrik nyala daerah balekamba...
# 310  listrik area salam magelang mati an pagi siang...
# 314       kakak daerah malang singosari mati lampu jam
#
#                                          Tokenize Text
# 0    [mohon, maaf, tidak, cantum, masalah, tuju, la...
# 1    [tindaklanjuti, tulis, aksi, ubah, komplain, j...
# 2    [admin, listrik, rumah, coba, hubung, pln, dek...
# 3                               [halo, admin, cek, dm]
# 5             [mudah, mudah, jam, depan, tidak, madam]
# ..                                                 ...
# 300  [daerah, balekambang, kramat, jati, jakarta, t...
# 304       [va, masuk, r, daya, va, alami, naik, tidak]
# 309  [assalamualaikum, listrik, nyala, daerah, bale...
# 310  [listrik, area, salam, magelang, mati, an, pag...
# 314  [kakak, daerah, malang, singosari, mati, lampu...
#
# [156 rows x 7 columns]
